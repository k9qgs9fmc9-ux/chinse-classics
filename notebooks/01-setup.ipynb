# %% [markdown]
# # 01. 环境搭建教程
#
# 本教程将指导您完成开发环境的搭建。
#
# ## 1. Python 环境
#
# 确保您已安装 Python 3.11+。

# %%
# !python --version

# %% [markdown]
# ## 2. 安装依赖
#
# 运行以下命令安装后端依赖：

# %%
# !pip install -r ../backend/requirements.txt
